# %%
import pandas as pd
date=pd.read_csv('../data/room911/senti_feature_frag_room911danmu0209.csv')
# display(date)
date['time'].to_csv('../data/room911/highlight_room911danmu0209.csv',index=None,header=True)

# %%
import pandas as pd
date=pd.read_csv('../data/room36252/frag_feature_room36252_0319.csv')
# display(date)
date['time'].to_csv('../data/room36252/highlight_room36252danmu0319.csv',index=None,header=True)

# %%
import pandas as pd
date=pd.read_csv('../data/room911/senti_frag_feature_room911danmu0203.csv')
# display(date)
date['time'].to_csv('../data/room911/highlight_room911danmu0203.csv',index=None,header=True)

# %%
import pandas as pd
date=pd.read_csv('../data/room911/senti_frag_feature_room911danmu0204.csv')
# display(date)
date['time'].to_csv('../data/room911/highlight_room911danmu0204.csv',index=None,header=True)

# %%
import pandas as pd
data=pd.read_csv('../data/room36252/highlight_room36252danmu0319 - 副本.csv')
# display(data)
model_flag=data['model_flag'].tolist()
data['human_flag']=model_flag
display(data)
data.to_csv('../data/room36252/highlight_room36252danmu0319.csv',index=None)
# Out:
#                 time human_flag model_flag
# 0    2020/3/19 16:30        NaN        NaN
# 1    2020/3/19 16:31        NaN        NaN
# 2    2020/3/19 16:32        NaN        NaN
# 3    2020/3/19 16:33        NaN        NaN
# 4    2020/3/19 16:34        NaN        NaN
# 5    2020/3/19 16:35        NaN        NaN
# 6    2020/3/19 16:36        NaN        NaN
# 7    2020/3/19 16:37        NaN        NaN
# 8    2020/3/19 16:38        NaN        NaN
# 9    2020/3/19 16:39        NaN        NaN
# 10   2020/3/19 16:40        NaN        NaN
# 11   2020/3/19 16:41        NaN        NaN
# 12   2020/3/19 16:42        NaN        NaN
# 13   2020/3/19 16:43          0          0
# 14   2020/3/19 16:44        NaN        NaN
# 15   2020/3/19 16:45        NaN        NaN
# 16   2020/3/19 16:46          1          1
# 17   2020/3/19 16:47        NaN        NaN
# 18   2020/3/19 16:48        NaN        NaN
# 19   2020/3/19 16:49        NaN        NaN
# 20   2020/3/19 16:50        NaN        NaN
# ...
