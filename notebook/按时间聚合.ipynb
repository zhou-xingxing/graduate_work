# %%
import pandas as pd 
data=pd.read_csv(r'../code/cleaned_test_room911_20000.csv')
data.columns=['id','time','content']
handle_time=lambda x: int(x)
data["time"]=data["time"].apply(handle_time)
# data["time"]=pd.to_datetime(data.time.values,unit="s",utc=True).tz_convert('Asia/Shanghai').strftime("%Y-%m-%d %H:%M:%S")


# 按30s进行聚和 加一个新列

fragment=[]
frag_num=0
start_time=data['time'][0]
for index,row in data.iterrows():
    if row['time']>=start_time and row['time']<start_time+30:
        fragment.append(frag_num)
    else:        
        start_time+=30
        frag_num+=1
        while row['time']>=start_time+30:
            start_time+=30
            frag_num+=1
        fragment.append(frag_num)    
data['fragment']=fragment
display(data)
# Out:
#               id        time                              content  fragment
# 0      195593304  1580122213                             游戏声音调大一点         0
# 1      154608277  1580122214                                  我我我         0
# 2      190260960  1580122214                                  111         0
# 3      315632047  1580122214                                  ...         0
# 4      186496778  1580122214                                  666         0
# 5      190834421  1580122214                              白哥打过来球吗         0
# 6      181465949  1580122215                                gg哈哈哈         0
# 7      161117397  1580122215                                  哈哈哈         0
# 8      185047545  1580122215                               昨天干嘛去了         0
# 9      219773612  1580122216                              你怎么不进张良         0
# 10     144704483  1580122216                                  未成年         0
# 11     185305829  1580122216                                  哈哈哈         0
# 12     214937944  1580122216  荧光棒❌ 荧光棒❌ 荧光棒❌ 不要送,周末有1.5倍亲密度❗️❗️❗️         0
# 13     185212733  1580122216            荧光棒不交🎉🎉小道具留一下🎈🎈周六周日1.5倍✨✨         0
# 14      16013272  1580122216                              未成年进不去的         0
# 15     261200472  1580122216                    没有通知,白哥...进来才看见播了         0
# 16     238285091  1580122217                                 沉迷手机         0
# 17     194783163  1580122217                          kanbujianne         0
# 18     295012443  1580122217                                 应该有啊         0
# 19     156138655  1580122217                           现在网吧还没关业吗?         0
# 20     182802417  1580122217                                   上学         0
# 21       2411213  1580122218                                都是同一批         0
# 22     335192568  1580122218                              以前的年轻人呗         0
# 23     189140604  1580122218               院士死了也没见你们这么哀悼,黑曼巴死了咋了?         0
# 24     201086922  1580122218                             隔离隔离隔离隔离         0
# 25     209406474  1580122219                            最近不都不营业嘛?         0
# 26     137411374  1580122219                           白哥这个皮肤手感咋样         0
# 27     144704483  1580122219                                  进不去         0
# 28      60281696  1580122219                                  233         0
# 29     153991852  1580122219                                沉迷手机了         0
# ...          ...         ...                                  ...       ...
# 19769  174780731  1580124922                            肌肉猛男,像你一样        90
# 19770  216176144  1580124922                                  哈哈哈        90
# 19771  307252728  1580124922                               没有头哈哈哈        90
# 19772  185618528  1580124922                            这皮肤肯定要返厂.        90
# 19773   33922095  1580124922                                熊二!!!        90
# 19774  253989418  1580124922                                  哈哈哈        90
# 19775  227278810  1580124922                                   熊大        90
# 19776  189069608  1580124922                           鲁班的皮肤好像女的呀        90
# 19777  329682462  1580124922                                   熊二        90
# 19778   45740243  1580124938                                踮脚...        90
# 19779  213872060  1580124938                                  哈哈哈        90
# 19780  225423295  1580124938                               哈哈哈笑死了        90
# 19781  246539808  1580124938                                这不熊大吗        90
# 19782  290556515  1580124938                              感觉有点熊出没        90
# 19783  195793254  1580124938                                  哈哈哈        90
# 19784  215734886  1580124938                                  像熊大        90
# 19785  145386530  1580124938                                   熊大        90
# 19786  197320478  1580124938                                   熊二        90
# 19787  198767928  1580124938                                这是猩猩吧        90
# 19788  241361825  1580124938                             穿着aj了 很拽        90
# 19789   63164251  1580124938                                韩信!!!        90
# 19790  256741828  1580124938                              笑死我了😂😂😂        90
# 19791  214088573  1580124938                                   熊二        90
# 19792   25584162  1580124938                                蹦哒蹦哒的        90
# 19793  239993940  1580124938                                   熊大        90
# 19794  193669878  1580124938                                   熊二        90
# 19795   14508970  1580124938                                  詹姆斯        90
# 19796  259244754  1580124938                                  熊大.        90
# 19797  141089258  1580124938                                熊二哈哈哈        90
# 19798  203191764  1580124938                             说好的肌肉猛男呢        90
#
# [19799 rows x 4 columns]

# %%
pd.set_option("display.max_rows", 1000)
# data["time"]=pd.to_datetime(data.time.values,unit="s",utc=True).tz_convert('Asia/Shanghai').strftime("%Y-%m-%d %H:%M:%S")
# display(data) 
data.to_csv(r'../code/frag_cleaned_test_room911_20000.csv',index=None)
