# %%
import pandas as pd
not_words=pd.read_csv(r'../dict/self_not.txt',header=None)
# display(not_words)
not_words.drop_duplicates(inplace=True)
display(not_words)
not_words.to_csv(r'../dict/self_not.txt',header=None,index=None)
# Out:
#        0
# 0      非
# 1      不
# 2      无
# 3      别
# 4      甭
# 5      未
# 6      莫
# 7      勿
# 8      白
# 9      忌
# 10     弗
# 11     否
# 12     休
# 13     没
# 14    没有
# 15    不要
# 16    不是
# 17    不用
# 18    不必
# 19    不曾
# 20    不太
# 21    无须
# 22    并非
# 23    毫无
# 24    决不
# 25    休想
# 26    永不
# 27    未尝
# 28    从不
# 29    从未
# ..   ...
# 46    不及
# 47    不如
# 48    不大
# 49    不甚
# 50   不怎么
# 51   没怎么
# 52   不可以
# 53   怎么不
# 54   几乎不
# 55   从来不
# 56    不该
# 57    不会
# 58    不好
# 59    不能
# 60    很少
# 61    极少
# 62    缺乏
# 63    缺少
# 64     反
# 65    请勿
# 66     毋
# 67  从未有过
# 68    一无
# 69    并未
# 70    尚无
# 71    绝不
# 72    毫不
# 73    白搭
# 74    无有
# 75    不够
#
# [76 rows x 1 columns]

# %%
pos=pd.read_csv(r'../dict/self_positive_dict.txt',header=None)
neg=pd.read_csv(r'../dict/self_negative_dict.txt',header=None)

posw=pos[0].tolist()
negw=neg[0].tolist()



notw=not_words[0].tolist()
print(len(posw),len(negw),len(notw))

for i in notw:
    if i in posw:
        print(i,'pos')
    if i in negw:
        print(i,'neg')
# Out:
# 10341 13927 76
# 非 neg
# 白 pos
# 白 neg
# 忌 pos
# 忌 neg
# 否 neg
# 没有 neg
# 不要 neg
# 不是 neg
# 不太 neg
# 毫无 pos
# 毫无 neg
# 从不 pos
# 未必 neg
# 难以 neg
# 尚未 neg
# 白白 neg
# 不如 neg
# 不大 neg
# 不会 neg
# 不好 neg
# 不能 neg
# 缺乏 neg
# 缺少 neg
# 反 neg
# 绝不 neg
# 毫不 pos
# 白搭 neg
# 不够 neg
