# %%
import pandas as pd
not_words=pd.read_csv(r'../dict/self_not.txt',header=None)
# display(not_words)
not_words.drop_duplicates(inplace=True)
display(not_words)
not_words.to_csv(r'../dict/self_not.txt',header=None,index=None)
# Out:
#        0
# 0      不
# 1      无
# 2      别
# 3      甭
# 4      未
# 5      莫
# 6      勿
# 7      忌
# 8      弗
# 9      否
# 10     休
# 11     没
# 12    没有
# 13    不是
# 14    不用
# 15    不必
# 16    不曾
# 17    不太
# 18    无须
# 19    并非
# 20    毫无
# 21    决不
# 22    永不
# 23    未尝
# 24    从不
# 25    从未
# 26    未必
# 27    未曾
# 28    未能
# 29    难以
# 30    尚未
# 31    从没
# 32    绝非
# 33    远非
# 34    切莫
# 35    切勿
# 36    弗有
# 37    休要
# 38    木有
# 39    勿用
# 40    不大
# 41    不甚
# 42    不很
# 43   不怎么
# 44   没怎么
# 45   怎么不
# 46   几乎不
# 47   从来不
# 48    很少
# 49    极少
# 50    请勿
# 51     毋
# 52  从未有过
# 53    并未
# 54    尚无
# 55    绝不
# 56    毫不
# 57    无有

# %%
pos=pd.read_csv(r'../dict/self_positive_dict.txt',header=None)
neg=pd.read_csv(r'../dict/self_negative_dict.txt',header=None)

posw=pos[0].tolist()
negw=neg[0].tolist()



notw=not_words[0].tolist()
print(len(posw),len(negw),len(notw))

for i in notw:
    if i in posw:
        print(i,'pos')
    if i in negw:
        print(i,'neg')
# Out:
# 10324 13916 58
# 忌 neg
# 否 neg
# 毫不 pos

# %%
import pandas as pd
degree=pd.read_csv(r'../dict/new_self_degree.txt',header=None)
# display(degree)
pd.set_option('display.max_rows', None)


degree=degree[0].tolist()

pos=pd.read_csv(r'../dict/self_positive_dict.txt',header=None)
neg=pd.read_csv(r'../dict/self_negative_dict.txt',header=None)
not_words=pd.read_csv(r'../dict/self_not.txt',header=None)
posw=pos[0].tolist()
negw=neg[0].tolist()
notw=not_words[0].tolist()

print(len(posw),len(negw),len(notw))

for i in degree:
    if i in posw:
        print(i,'pos')
    if i in negw:
        print(i,'neg')
    if i in notw:
        print(i,'not')
# Out:
# 10334 13921 59
# 极度 neg
# 极端 neg
# 过 pos
# 过度 neg
# 绝对 neg
# 完全 pos
# 无比 pos
# 特别 pos
# 格外 neg
# 怪 neg
# 老 neg
# 相当 pos
# 好 pos
# 蛮 neg
# 满 pos
# 满 neg
# 确实 pos
# 的确 pos
# 还 pos
# 丝毫 neg
# 有点儿 neg
# 略 pos

# %%
import pandas as pd
degree=pd.read_csv(r'../dict/new_self_degree.txt',header=None)

pd.set_option('display.max_rows', None)
display(degree)
degree=degree[0].tolist()
most=degree[:17]
more=degree[17:55]
less=degree[55:70]
least=degree[70:]
print(most)
print(more)
print(less)
print(least)

dic={'most':most,'more':more,'less':less,'least':least}

# fw = open("../dict/self_degree.txt",'w') 
# fw.write(str(dic)) #把字典转化为str 
# fw.close()
# Out:
#        0
# 0      最
# 1     最为
# 2      极
# 3     极为
# 4     极其
# 5     极度
# 6     过于
# 7     万分
# 8     绝对
# 9     完全
# 10    至极
# 11    何止
# 12  百分之百
# 13    无比
# 14    特别
# 15     太
# 16     忒
# 17     更
# 18    更加
# 19    更为
# 20    分外
# 21     越
# 22    越发
# 23    倍加
# 24     愈
# 25    愈加
# 26    愈发
# 27   愈来愈
# 28    愈益
# 29   越来越
# 30    越加
# 31    格外
# 32     很
# 33     挺
# 34     怪
# 35     老
# 36    非常
# 37    相当
# 38    十分
# 39     好
# 40     甚
# 41     颇
# 42     蛮
# 43     够
# 44     多
# 45    多么
# 46    那么
# 47    这么
# 48    何等
# 49    何其
# 50    尤其
# 51    尤为
# 52    着实
# 53    确实
# 54    的确
# 55     还
# 56     较
# 57    比较
# 58    较为
# 59    相对
# 60    还算
# 61    未免
# 62    基本
# 63   基本上
# 64    有些
# 65    一些
# 66  或多或少
# 67    多少
# 68  多多少少
# 69    些许
# 70    丝毫
# 71    轻度
# 72    半点
# 73   半点儿
# 74    一点
# 75   一点儿
# 76    有点
# 77   有点儿
# 78     稍
# 79    稍稍
# 80    稍微
# 81    稍为
# 82    稍许
# 83     略
# 84    略略
# 85    略微
# 86    略为
# 87    些微
# ['最', '最为', '极', '极为', '极其', '极度', '过于', '万分', '绝对', '完全', '至极', '何止', '百分之百', '无比', '特别', '太', '忒']
# ['更', '更加', '更为', '分外', '越', '越发', '倍加', '愈', '愈加', '愈发', '愈来愈', '愈益', '越来越', '越加', '格外', '很', '挺', '怪', '老', '非常', '相当', '十分', '好', '甚', '颇', '蛮', '够', '多', '多么', '那么', '这么', '何等', '何其', '尤其', '尤为', '着实', '确实', '的确']
# ['还', '较', '比较', '较为', '相对', '还算', '未免', '基本', '基本上', '有些', '一些', '或多或少', '多少', '多多少少', '些许']
# ['丝毫', '轻度', '半点', '半点儿', '一点', '一点儿', '有点', '有点儿', '稍', '稍稍', '稍微', '稍为', '稍许', '略', '略略', '略微', '略为', '些微']

# %%
fw = open("../dict/self_degree.txt",'r',encoding='utf-8') 
dict=eval(fw.read()) #把字典转化为str 
fw.close()
print(dict)
for i in dict:
    print(len(dict[i]))
# Out:
# {'most': ['最', '最为', '极', '极为', '极其', '极度', '过于', '万分', '绝对', '完全', '至极', '何止', '百分之百', '无比', '特别', '太', '忒'], 'more': ['更', '更加', '更为', '分外', '越', '越发', '倍加', '愈', '愈加', '愈发', '愈来愈', '愈益', '越来越', '越加', '格外', '很', '挺', '怪', '老', '非常', '相当', '十分', '好', '甚', '颇', '蛮', '够', '多', '多么', '那么', '这么', '何等', '何其', '尤其', '尤为', '着实', '确实', '的确'], 'less': ['还', '较', '比较', '较为', '相对', '还算', '未免', '基本', '基本上', '有些', '一些', '或多或少', '多少', '多多少少', '些许'], 'least': ['丝毫', '轻度', '半点', '半点儿', '一点', '一点儿', '有点', '有点儿', '稍', '稍稍', '稍微', '稍为', '稍许', '略', '略略', '略微', '略为', '些微']}
# 17
# 38
# 15
# 18

# %%
for j in [1,2]:
    print(j)
# Out:
# 1
# 2
